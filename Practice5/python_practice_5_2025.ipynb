# %% [markdown]
# # I. OOP

# %% [markdown]
# 1. (6б). Створіть клас Building, додайте три атрибути, один з яких має значення за замовчуванням та два методи на свій розсуд.

# %%
class Building:
    def __init__(self, name, floors, material="Brick"):
        self.name = name
        self.floors = floors
        self.material = material

    def AddFloor(self):
        self.floors += 1

    def rebuild(self, material):
        self.material = material

# %% [markdown]
# 2. (2б). Створіть два обʼєкти цього класу, де один з обʼєктів створюється із дефолтним значенням атрибуту. На одному обʼєкті отримайте значення його атрибуту, а на іншому викличте один з його методів.

# %%
skyscraper = Building("Skyscraper", 50, "Metal")
normalHouse = Building("House", 1)

print(normalHouse.material)
skyscraper.AddFloor()
# Out:
# Brick

# %% [markdown]
# 3. (5б). Створіть клас, де атрибути мають різні рівні доступу. Спробуйте отримати їхні значення та опишіть результати.

# %%
class Building2:
    def __init__(self, name, floors, material="Brick"):
        self.name = name
        self._floors = floors
        self.__material = material


skyscraper = Building2("Skyscraper", 50, "Metal")

print("Name:" + skyscraper.name)
print("\nFloors:" + str(skyscraper._floors))
print("\nMaterial:" + skyscraper._Building2__material)
# Out:
# Name:Skyscraper
#
# Floors:50
#
# Material:Metal

# %% [markdown]
# 4. (7б). Як ви розумієте термін self? Для чого використовується метод __init __?

# %% [markdown]
# self - Сам об'єкт
#
# __init__ - використовується при ініціалізації

# %% [markdown]
# 5. (9б). Створіть клас 3D-фігура без атрибутів, з методом get_volume для отримання об'єму фігури, що повертає 0 та __add __, який приймає self та other в якості аргументів, а повертає суму об'ємів 3d-фігур self та other.

# %%
class Object3D:
  def getVolume(self):
    return 0

  def __add__(self, other):
    return self.getVolume() + other.getVolume()

# %% [markdown]
# 6. (11б). Створіть 2 дочірніх класи від 3d-фігура: Циліндр та Куб, які мають атрибути, необхідні для розрахунку об'єму. Визначте метод get_volume в кожному з них так, щоби вони розраховували об'єм у залежності від формули для кожного типу фігури. Створіть обʼєкт класу Циліндр та обʼєкт класу Куб. Виконайте операцію суми за допомогою оператора + між ними, аби знайти сумарний об'єм.

# %%
import math

class Cylinder(Object3D):
  def __init__ (self, height, radius):
    self.radius = radius
    self.height = height;

  def getVolume(self):
     return self.height * self.radius ** 2 * math.pi


class Cube(Object3D):
  def __init__ (self, side):
    self.side = side;

  def getVolume(self):
     return self.side ** 3


cyl = Cylinder(10, 5)
cube = Cube(3)

print(cyl.getVolume() + cube.getVolume())
# Out:
# 812.3981633974482

# %% [markdown]
# 7. (3б). Продемонструйте різницю між isinstance та issubclass.

# %%
print(str(isinstance(cyl, Cylinder)) + "\n")
print(str(isinstance(cyl, Object3D)) + "\n")
try:
  print(str(issubclass(cyl, Object3D)) + "\n")
except:
  print("False\n")
print(str(issubclass(Cylinder, Object3D)) + "\n")
# Out:
# True
#
# True
#
# False
#
# True

# %% [markdown]
# 8. (13б). Створіть клас EWallet з приватними атрибутами balance та id. Реалізуйте методи поповнення та зняття коштів, забезпечивши належну інкапсуляцію. Підказка: використовуйте декоратори property та setter.

# %%
class EWallet:
  def __init__ (self, ballance, id):
    self.__ballence = ballance
    self.__id = id

    @property
    def balance(self):
        return self.__balance

    @balance.setter
    def balance(self, value):
        self.__balance = value

# %% [markdown]
# 9. (11б). Створіть клас ShoppingCart, який містить список об'єктів типу Item. Реалізуйте методи для додавання айтемів, їх видалення та відображення списку айтемів.

# %%
class ShoppingCart:
  def __init__ (self):
    self.items = []

  def addItem(self, item):
    self.items.append(item)

  def removeItem(self, item):
    self.items.remove(item)

  def showItems(self):
    for item in self.items:
      print(item)

# %% [markdown]
# 10. (13б). Створіть клас Vehicle з атрибутами brand (manufacturer) та production_age. Створіть ще один клас Engine з такими атрибутами, як type (ex. petrol) та size (volume, litres). Створіть клас Car, який успадковує обидва класи Vehicle та Engine. Продемонструйте використання множинної спадковості, створивши обʼєкт класу Car та отримавши mro для цього класу.

# %%
class Vehile:
  def __init__(self, brand, productionAge):
    self.brand = brand
    self.productionAge = productionAge

class Engine:
  def __init__ (self, type, size):
    self.type = type
    self.size = size

class Car(Engine, Vehile):
  def __init__ (self, brand, productionAge, type, size):
    Vehile.__init__(brand, productionAge)
    Engine.__init__(type, size)

Car.mro()
# Out:
# [__main__.Car, __main__.Engine, __main__.Vehile, object]

# %% [markdown]
# # II. Iterator

# %% [markdown]
# 11. (4б). Визначте рядок(str) з 4ма різними за значенням символами. Створіть ітератор на основі цього рядка. Викличте 5 разів функцію next на ітераторі, 4ри перших з них огорніть у ф-цію print().

# %%
string = "abcd"
iterator = iter(string)

print(next(iterator))
print(next(iterator))
print(next(iterator))
print(next(iterator))
try:
  print(next(iterator))
except:
  print("Iterator failed")
# Out:
# a
# b
# c
# d
# Iterator failed

# %% [markdown]
# А що якщо викликати цю ж функцію на рядку?

# %%
print(next(string))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1995612670.py in <cell line: 0>()
# ----> 1 print(next(string))
#
# TypeError: 'str' object is not an iterator

# %% [markdown]
#  12. (5б). Опишіть своїми словами в одному реченні, як ви розумієте різницю між ітерабельними обʼєктами та ітераторами (можна на прикладі).

# %% [markdown]
# Ітерабельний об'єкт - об'єкт, який можна перетворити на ітератор
#
# Ітератор - об'єкт який проходитб по всім об'єктам в ітерабельному об'єкті

# %% [markdown]
# 13. (11б). Створіть клас, що має визначений Iterator Protocol та при кожному виклику next повертає назву дня тижня, поки вони не вичерпаються. Зверніть увагу, що порядок має значення.

# %%
class Week:
  def __init__ (self):
    self.days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
    self.end = 7
    self.current = 0

  def __iter__(self):
    return self

  def __next__ (self):
    if self.current < self.end:
      day = self.days[self.current]
      self.current += 1
      return day
    else:
      raise StopIteration
      # self.current = 0
      # self.__next__()

# %% [markdown]
# # Вітаю! Ви велика(ий) молодець, що впоралась(вся). Похваліть себе та побалуйте чимось приємним. Я Вами пишаюся.
